# %% [markdown]
# ## Data processing for the food2fork project
#
# Using the food2fork API, we were able to retrieve information about ~30000 online recipes. We stored all of this information in a MongoDB database. Before we can do anything with it, we need to parse and clean up the data.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient('mongodb://localhost:27017')
dbfood = client.food2forkDB.food2fork

# %% [markdown]
# Let's create a dataframe with all of the data from the database

# %%
df = pd.DataFrame.from_records(dbfood.find())
df.head()
# Out:
#                         _id    cooktime difficulty  \
# 0  5ac80bcf9e7c096d8774e2e3        PT6M        NaN
# 1  5ac80cd49e7c096d8774e2e6         NaN        NaN
# 2  5ac80cd69e7c096d8774e2e7  45 Minutes        NaN
# 3  5ac80cd99e7c096d8774e2e8       PT15M        NaN
# 4  5ac80cda9e7c096d8774e2e9       PT10M        NaN
#
#                            f2f_url  \
# 0  http://food2fork.com/view/35382
# 1  http://food2fork.com/view/47024
# 2  http://food2fork.com/view/47319
# 3  http://food2fork.com/view/54384
# 4  http://food2fork.com/view/35171
#
#                                            image_url  \
# 0  http://static.food2fork.com/Jalapeno2BPopper2B...
# 1     http://static.food2fork.com/icedcoffee5766.jpg
# 2  http://static.food2fork.com/CrashHotPotatoes57...
# 3  http://static.food2fork.com/avocadomacandchees...
# 4  http://static.food2fork.com/Buffalo2BChicken2B...
#
#                                                media nutrition    preptime  \
# ...

# %%
df.count()
# Out:
# _id                29972
# cooktime           18083
# difficulty          5989
# f2f_url            29972
# image_url          29972
# media              29972
# nutrition           8888
# preptime           13858
# publisher          29972
# publisher_url      29972
# rating             18164
# raw_ingredients    29972
# recipe_id          29972
# reviews            18158
# social_rank        29972
# source_url         29972
# title              29972
# dtype: int64

# %% [markdown]
# ### Social media ranking

# %%
df['media_likes'] = df['media'].map(lambda x: x.get('likes', 0))
df['media_tweets'] = df['media'].map(lambda x: x.get('tweets', 0))
df['media_plusses'] = df['media'].map(lambda x: x.get('plusses', 0))
df['media_pins'] = df['media'].map(lambda x: x.get('pins', 0))
df['media_views'] = df['media'].map(lambda x: x.get('views', 0))

# %%
df['nmedia_likes'] = df['media_likes']/df['media_likes'].sum()
df['nmedia_tweets'] = df['media_tweets']/df['media_tweets'].sum()
df['nmedia_plusses'] = df['media_plusses']/df['media_plusses'].sum()
df['nmedia_pins'] = df['media_pins']/df['media_pins'].sum()
df['nmedia_views'] = df['media_views']/df['media_views'].sum()

df['media_rank'] = (df['nmedia_likes'] + df['nmedia_tweets'] +
                    df['nmedia_plusses'] + df['nmedia_pins'] +
                    df['nmedia_views'])

# %%
sdf = df.sort_values(by='media_rank', ascending=False)
sdf.head()
# Out:
#                            _id    cooktime difficulty  \
# 2     5ac80cd69e7c096d8774e2e7  45 Minutes        NaN
# 3689  5ac84abd9e7c096d8774f150       PT15M        NaN
# 9     5ac80ce49e7c096d8774e2ee         NaN        NaN
# 1     5ac80cd49e7c096d8774e2e6         NaN        NaN
# 198   5ac80f1d9e7c096d8774e3ab         NaN        NaN
#
#                                f2f_url  \
# 2      http://food2fork.com/view/47319
# 3689    http://food2fork.com/view/3757
# 9     http://food2fork.com/view/713134
# 1      http://food2fork.com/view/47024
# 198   http://food2fork.com/view/19d885
#
#                                               image_url  \
# 2     http://static.food2fork.com/CrashHotPotatoes57...
# 3689         http://static.food2fork.com/225844ae6e.jpg
# 9     http://static.food2fork.com/ParmesanRoastedPot...
# 1        http://static.food2fork.com/icedcoffee5766.jpg
# 198          http://static.food2fork.com/353269d44b.jpg
#
# ...

# %% [markdown]
# #### Most popular online recipes

# %%
sdf = sdf.reset_index(drop=True)
sdf.loc[:20, ['title', 'media_rank']].set_index('title', drop=True).plot(kind='bar')

# %% [markdown]
# #### Difficulty vs Popularity

# %%
df['difficulty'].unique()
# Out:
# array([nan, 'Easy', 'Medium', 'Super easy', 'More effort', 'A challenge',
#        'Not too tricky', 'Hard', 'Intermediate'], dtype=object)

# %%
diff_df = df[['difficulty', 'media_rank']].dropna()
diff_df.head()
# Out:
#     difficulty  media_rank
# 76        Easy    0.008786
# 85      Medium    0.011004
# 104       Easy    0.014228
# 130       Easy    0.002571
# 132       Easy    0.000865

# %%
difficulties = ['Super easy', 'Easy', 'Not too tricky', 'Intermediate', 'Medium', 'More effort', 'Hard', 'A challenge']
diff_gp = diff_df.groupby('difficulty')
diff_gp.describe()
# Out:
#                media_rank                                                    \
#                     count      mean       std       min       25%       50%
# difficulty
# A challenge          58.0  0.000138  0.000279  0.000011  0.000018  0.000032
# Easy               4826.0  0.000102  0.000409  0.000010  0.000019  0.000037
# Hard                 26.0  0.000093  0.000100  0.000012  0.000027  0.000055
# Intermediate         81.0  0.000174  0.000549  0.000010  0.000014  0.000029
# Medium              220.0  0.000121  0.000741  0.000011  0.000026  0.000049
# More effort         346.0  0.000070  0.000154  0.000010  0.000017  0.000029
# Not too tricky       79.0  0.000286  0.000507  0.000011  0.000031  0.000073
# Super easy          353.0  0.000184  0.000353  0.000011  0.000022  0.000054
#
#
#                      75%       max
# difficulty
# A challenge     0.000114  0.001425
# Easy            0.000077  0.014228
# Hard            0.000141  0.000448
# Intermediate    0.000060  0.003294
# ...

# %%
diff_gp.median().loc[difficulties].plot(kind='bar')

# %%
diff_df.boxplot(by='difficulty', rot=45, showfliers=False)
plt.ylabel('Media rank')

# %% [markdown]
# ### Time parsing
#
# Here we will transform the time strings into a number of minutes

# %%
from dateutil.parser import parse
import re

def parse_time(string):
    if not isinstance(string, str):
        return
    try:
        time = parse(string)
        return time.hour*60+time.minute
    except ValueError:
        pass
    match = re.match('^PT(([\d\.]+)H)?((\d+)M)?', string)
    if match:
        hrs = float(match.group(2) or 0)
        mins = float(match.group(4) or 0)
        return hrs*60+mins

    pattern = (r'^\s*((?P<hours>\d+)\s*(h|h(ou)?rs?))?[\s,]*'
               r'((?P<minutes>\d+)\s*(m|mins?|minutes))?\s*(plus\s.*)?$')
    match = re.match(pattern, string, re.IGNORECASE)
    if match:
        hrs = int(match.group('hours') or 0)
        mins = int(match.group('minutes') or 0)
        return hrs*60+mins
    
    if '-' in string:
        spl = string.split('-')
        return sum(parse_time(item) for item in spl)
    else:
        print(string)


df['cooktime_mins'] = df['cooktime'].map(parse_time)
df['preptime_mins'] = df['preptime'].map(parse_time)
df['totaltime_mins'] = df['cooktime_mins'].fillna(0) + df['preptime_mins'].fillna(0)
# Out:
# 5 minutes per dressing
# P1DT

# %%
df[['cooktime', 'cooktime_mins', 'preptime', 'preptime_mins', 'totaltime_mins']].head(50)
# Out:
#                      cooktime  cooktime_mins                   preptime  \
# 0                        PT6M            6.0                      PT34M
# 1                         NaN            NaN                    8 Hours
# 2                  45 Minutes           45.0                 10 Minutes
# 3                       PT15M           15.0                      PT10M
# 4                       PT10M           10.0                       PT5M
# 5                  30 Minutes           30.0                    2 Hours
# 6                         NaN            NaN                      PT20M
# 7                        PT5M            5.0                       PT5M
# 8                     6 Hours          360.0                  5 Minutes
# 9                         NaN            NaN                        NaN
# 10                      PT20M           20.0                      PT10M
# 11                      PT35M           35.0                      PT25M
# ...

# %%
diff_df = df[['difficulty', 'totaltime_mins']].dropna()
diff_df = diff_df[(diff_df['totaltime_mins'] > 0.) & (diff_df['totaltime_mins'] < 1000.)]
diff_df.head()
# Out:
#     difficulty  totaltime_mins
# 76        Easy            15.0
# 85      Medium           120.0
# 104       Easy            13.0
# 130       Easy           150.0
# 132       Easy            90.0

# %% [markdown]
# #### Total cooking time vs difficulty

# %%
fig, ax = plt.subplots()
newdf = None
for j, diff in enumerate(difficulties):
    vals = diff_df.loc[diff_df['difficulty'] == diff, 'totaltime_mins'].values
    newdf1 = pd.DataFrame({diff: vals})
    if newdf is None:
        newdf = newdf1
    else:
        newdf = pd.concat([newdf, newdf1], axis=1)

newdf.boxplot(rot=45, showfliers=False)
plt.ylabel('Total cooking time (in mins)')

# %% [markdown]
# ### Ingredient parsing
#
# We're using machine learning to parse the raw recipe ingredients into actual ingredients and get rid of quantities, units and comments

# %%
from food2fork.ingredient_parser import get_ingredient_from_phrase

# %%
df['ingredients'] = df['raw_ingredients'].map(lambda x: [get_ingredient_from_phrase(item) for item in x])

# %% [markdown]
# ### Find most common ingredients

# %%
from collections import Counter
from itertools import combinations

def count_ingredients(values, nsub=2):
    '''returns a counter of paired ingredients
    '''
    counter  = Counter()
    for sub in values:
        if len(values) < 2:
            continue
        sub.sort()
        if '' in sub:
            sub.remove('')
        if nsub == 1:
            iterator = sub
        else:
            iterator = combinations(sub, nsub)
        for comb in iterator:
            counter[comb] += 1
    return counter

counter = count_ingredients(df['ingredients'].values, nsub=1)

# %% [markdown]
# ### Recipe types
#
# We will use machine learning to categorize recipes between dessert, drink, ...

# %%
# First, let's get rid of the rare ingredients
df['ingredients2'] = df['ingredients'].map(lambda x: [item for item in x if item in counter and counter[item] > 50])

# %%
# How many unique ingredients do we have left?
def unique_items(values):
    return set([ing for inglist in values for ing in inglist])

print(len(unique_items(df['ingredients2'].values)))
# Out:
# 540

# %%
# now we need to encode the 540 unique ingredients to 540 columns
# subdf = df[['ingredients2']]
# print(len(subdf))
# Out:
# 29972

# %%
# subdf = pd.get_dummies(subdf['ingredients2'].apply(pd.Series).stack()).sum(level=0)
# print(len(subdf))
# Out:
# 29753

# %%
# subdf['title'] = df['title']
# subdf['recipe_type'] = ''
# subdf.head()

# %%
# sample = subdf.sample(n=500)

# j = 0
# for index, row in sample.iterrows():
#     ans = input(f"{j}, {row['title']}: ")
#     if ans == 'd':
#         val = 'dessert'
#     elif ans == 'k':
#         val = 'drink'
#     else:
#         val = 'main'
#     sample.set_value(index,'recipe_type', val)
#     j += 1
# Out:
# 0, Bacon-Wrapped Potatoes With Creamy Dill Sauce:
# 1, Terry's Texas Pinto Beans:
# 2, Tequila-Glazed Chicken With Jalapeno:
# 3, Plum and Peach Crisp: d
# 4, Clam, Chard, and Bacon Pizza:
# 5, Flatlander Chili:
# 6, Roasted Broccoli and Grilled Cheese Melt:
# 7, Peppermint Patties: d
# 8, Summer Harvest Naan Pizza Recipe with Corn, Tomatoes & Jalapeo:
# 9, Chicken Enchiladas V:
# 10, Sweet Potato Casserole With Coconut:
# 11, Jumbo Lemon Coffee Cake Muffins: d
# 12, Jerk Chicken Tacos with Tropical Salsa:
# 13, Breakfast Pizza I:
# 14, Quick Chicken Divan:
# 15, Bacon Double Cheese Burger Dip:
# 16, Halloumi skewers with parsley &amp; lemon salsa:
# 17, Spicy bean &amp; corn dip:
# 18, Barbecued Chicken on the Grill:
# 19, Gingerbread bundt cake: d
# 20, Slow-Cooked Lamb with Sage and Pearl Barley:
# 21, Steak with Creamy Whiskey Mushroom Sauce Recipe:
# 22, Oatmeal Chocolate Chip Pancakes: d
# 23, Kimchi Fritters with Soy Dipping Sauce:
# 24, Rhubarb Crumble: d
# 25, Cannoli: d
# ...

# %%
# len(sample)
# Out:
# 500

# %%
# from sklearn.model_selection import train_test_split

# X = sample.iloc[:, :-2]
# y = sample.iloc[:, -1]

# x_train, x_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
# from sklearn.linear_model import LogisticRegression

# logreg = LogisticRegression()
# logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# print(f'Training score: {logreg.score(x_train, y_train)}')
# print(f'Testing score: {logreg.score(x_test, y_test)}')
# Out:
# Training score: 0.976
# Testing score: 0.928

# %%
# subdf['recipe_type'] = logreg.predict(subdf.iloc[:, :-2])

# %%
# # Saving the model
# import pickle

# with open('recipe_type.model', 'wb') as outfil:
#     pickle.dump(logreg, outfil)

# %%
# Loading the model for testing
import pickle

with open('recipe_type.model', 'rb') as fil:
    model = pickle.load(fil)

# model.predict(subdf.iloc[:10, :-2])

# %%
newdf = df[['ingredients2']]

# %%
for ing in sorted(unique_items(df['ingredients2'].values)):
    newdf[ing] = 0
print(len(newdf))
print(len(newdf.columns))
# Out:
# /Users/cooldjules/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 29972
# 541

# %%
for index, row in newdf.iterrows():
    for ing in row['ingredients2']:
        newdf.set_value(index, ing, 1)

# %%
df['recipe_type'] = model.predict(newdf.iloc[:, 1:])

# %%
df.head(20)
# Out:
#                          _id    cooktime difficulty  \
# 0   5ac80bcf9e7c096d8774e2e3        PT6M        NaN
# 1   5ac80cd49e7c096d8774e2e6         NaN        NaN
# 2   5ac80cd69e7c096d8774e2e7  45 Minutes        NaN
# 3   5ac80cd99e7c096d8774e2e8       PT15M        NaN
# 4   5ac80cda9e7c096d8774e2e9       PT10M        NaN
# 5   5ac80cdd9e7c096d8774e2ea  30 Minutes        NaN
# 6   5ac80cdf9e7c096d8774e2eb         NaN        NaN
# 7   5ac80ce19e7c096d8774e2ec        PT5M        NaN
# 8   5ac80ce39e7c096d8774e2ed     6 Hours        NaN
# 9   5ac80ce49e7c096d8774e2ee         NaN        NaN
# 10  5ac80ce69e7c096d8774e2ef       PT20M        NaN
# 11  5ac80ce99e7c096d8774e2f0       PT35M        NaN
# 12  5ac80cea9e7c096d8774e2f1       PT20M        NaN
# 13  5ac80ced9e7c096d8774e2f2         NaN        NaN
# 14  5ac80cf09e7c096d8774e2f3         NaN        NaN
# 15  5ac80cf29e7c096d8774e2f4  30 Minutes        NaN
# 16  5ac80cf49e7c096d8774e2f5       PT25M        NaN
# ...

# %% [markdown]
# ### Curated ingredients
#
# After parsing the ingredients, we will curate them to keep only relevant ingredients. For that purpose, we're using a list of ingredients to ignore, a dictionary to map ingredients (for example, tomato and tomato juice will be considered the same ingredient for the purpose of food pairing).
#
# We also manually categorized ingredients into a few categories: spice, herb, meat, dairy, produce, nut and other. For this project, we will not use the `other` category. We will also discard all dessert recipes.

# %%
newdf = df[df['recipe_type'] == 'main']
print(len(newdf))
# Out:
# 22558

# %%
ignore = ['salt',
    'butter',
    'olive oil',
    'sugar',
    'eggs',
    'black pepper',
    'vanilla extract',
    'water',
    'all-purpose flour',
    'kosher salt',
    'milk',
    'baking powder',
    'brown sugar',
    'unsalted butter',
    'flour',
    'baking soda',
    'egg',
    '',
    'vegetable oil',
    'white sugar',
    'salt pepper',
    'salt black pepper',
    'heavy cream',
    'sea salt',
    'extra-virgin olive oil',
    'sour cream',
    'cups',
    'whole whole',
    '1-',
    'asian sesame oil',
    'baby',
    'bag',
    'bag spinach',
    'black',
    'boiling water',
    'box',
    'breakfast sausage',
    'bun',
    'candy canes',
    'condensed cream mushroom soup',
    'condensed tomato soup',
    'dash',
    'dog',
    'dough',
    'egg water',
    'equipment',
    'extra virgin olive oil',
    'fillet',
    'filling',
    'fishmonger',
    'frosting',
    'fruit',
    'glac cherries',
    'glaze',
    'golden syrup',
    'green',
    'green food coloring',
    'ground pepper',
    'half',
    'hamburger buns',
    'heart',
    'heavy whipping cream',
    'herb',
    'ice cream',
    'ice water',
    'italian seasoning',
    'jar',
    'jar spaghetti sauce',
    'juice',
    'knob butter',
    'kosher',
    'kosher salt black pepper',
    'kosher salt pepper',
    'meat',
    'mix',
    'oil',
    'onion soup mix',
    'ounce',
    'packages packages',
    'panko',
    'pasta sauce',
    'pastry',
    'peel',
    'penne',
    'penne pasta',
    'pepper',
    'pico',
    'pizza dough',
    'pizza sauce',
    'pomegranate molasses',
    'popcorn',
    'popcorn kernels',
    'potato starch',
    'poultry seasoning',
    'pounds pounds',
    'puff pastry',
    'puy lentils',
    'ranch dressing',
    'red',
    'red food coloring',
    'rice cereal',
    'roast',
    'salad',
    'salad greens',
    'salt white pepper',
    'saltine crackers',
    'sauce',
    'sea salt black pepper',
    'sea salt pepper',
    'seasoning salt',
    'self-rising flour',
    'semisweet',
    'shortcrust pastry',
    'shortening',
    'skim milk',
    'skinless',
    'soba noodles',
    'soda water',
    'soft butter',
    'soft cheese',
    'spaghetti',
    'spaghetti sauce',
    'spice',
    'spray',
    'sprig',
    'sprinkle',
    'stalk',
    'steak sauce',
    'stock',
    'superfine sugar',
    'sweet onion',
    'table salt',
    'taco seasoning',
    'tea bags',
    'tomato sauce',
    'topping',
    'tortilla',
    'tortilla chips',
    'turbinado sugar',
    'vanilla wafers',
    'vegetable',
    'vegetable oil spray',
    'vegetable shortening',
    'whipped cream',
    'whipping cream',
    'white',
    'white flour',
    'white miso',
    'white pepper',
    'white rice',
    'white whole wheat flour',
    'whole',
    'whole black peppercorns',
    'whole milk',
    'whole wheat bread',
    'whole wheat flour',
    'whole wheat pastry flour',
    'whole wheat tortillas',
    'whole-wheat flour',
    'wholemeal flour',
    'wonton wrappers',
    'wooden skewers',
    'yellow cake mix',
    'zest',
    'zest juice',
    'zest juice lemon',
    'all purpose flour',
    'arborio rice',
    'baguette',
    'barley',
    'basmati rice',
    'bean',
    'berry',
    'biscuit',
    'bread',
    'bread crumbs',
    'bread flour',
    'broth',
    'brown rice',
    'buckwheat flour',
    'butterscotch chips',
    'cajun seasoning',
    'cake',
    'cake flour',
    'can',
    'cane sugar',
    'chocolate pudding mix',
    'chocolate syrup',
    'chuck',
    'coconut flour',
    'coconut oil',
    "confectioner 's sugar",
    'corn oil',
    'corn starch',
    'corn syrup',
    'corn tortillas',
    'cornflour',
    'cornmeal',
    'couscous',
    'cream',
    'creme fraiche',
    'creole seasoning',
    'crust',
    'dark brown sugar',
    'digestive biscuits',
    'double cream',
    'elbow macaroni',
    'enchilada sauce',
    'english muffins',
    'flour tortillas',
    'graham cracker crumbs',
    'graham crackers',
    'groundnut oil',
    'half-and-half',
    'ice',
    'icing sugar',
    'instant yeast',
    'jasmine rice',
    'ketchup',
    'lemon pepper',
    'linguine',
    'macaroni',
    'margarine',
    'marinara sauce',
    'masa harina',
    'milk powder',
    'miso paste',
    'molasses',
    'noodle',
    'nut',
    'onion salt',
    'orzo',
    'orzo pasta',
    'passata',
    'pasta',
    'pasta shells',
    'peanut oil',
    'peppercorn',
    'pie crust',
    'polenta',
    'potato chips',
    'powdered sugar',
    'rapeseed oil',
    'rice',
    'rice flour',
    'rice noodles',
    'risotto rice',
    'rye flour',
    'salsa',
    'seed',
    'self-raising flour',
    'semolina flour',
    'simple syrup',
    'skewer',
    'sourdough bread',
    'sugar',
    'sunflower oil',
    'syrup',
    'tablespoon',
    'teaspoon',
    'wheat flour',
    'wild rice',
    'wine',
    'wine vinegar',
    'yellow cornmeal',
    'caster sugar',
    'chocolate cake mix',
    'fettuccine',
    'oat',
    'pearl barley',
    'quinoa',
    'rigatoni',
    'active dry yeast',
    'all purpose flour',
    'almond butter',
    'almond flour',
    'bacon fat',
    'baguette',
    'bicarbonate soda',
    'canola oil',
    'chickpea flour',
    'chili oil',
    'clam juice',
    'club soda',
    'garlic salt',
    'gelatin',
    'grapeseed oil',
    'lard',
    'rice wine',
    'walnut oil',
    'wheat germ',
    'cream of tartar',
    'rice vinegar',
    'raspberry jam',
    'celery salt',
    'strawberry jam',
    'agave nectar',
    'eggnog',
    'egg noodles',
    'peppermint extract',
    'triple sec',
    'dill pickles',
    'lasagna noodles',
    'adobo sauce',
    'hot sauce',
    'american cheese',
    'almond milk'
]

mapping = {
    'gorgonzola cheese': "blue cheese",
    'tomato juice': 'tomato',
    'all-purpose gold flour': 'all purpose flour',
    'allspice berries': 'allspice',
    'anchovy fillets': 'anchovy',
    'asafoetida': 'asafetida',
    'aubergine': 'eggplant',
    'bacon bits': 'bacon bits',
    'baking potatoes': 'potato',
    'barbeque sauce': 'barbecue sauce',
    'bay seasoning': 'bay',
    'beef chuck roast': 'beef chuck',
    'bell peppers': 'bell pepper',
    'bittersweet chocolate': 'chocolate',
    'bittersweet chocolate chips': 'chocolate',
    'black peppercorns': '',
    'bramley apples': 'apple',
    'breadcrumb': 'bread crumbs',
    'brie cheese': 'brie',
    'broccoli florets': 'broccoli',
    'brown lentils': '',
    'bunch chives': 'chive',
    'button mushrooms': 'mushroom',
    'cacao powder': 'cocoa powder',
    'canola': 'canola oil',
    'cauliflower florets': 'cauliflower',
    'cayenne': 'cayenne pepper',
    'celery ribs': 'celery',
    'celery seed': 'celery seeds',
    'celery stalks': 'celery',
    'cheddar cheese': 'cheddar',
    'chestnut mushrooms': 'mushroom',
    'chicken bouillon granules': 'chicken broth',
    'chicken breast': 'chicken',
    'chicken thighs': 'chicken',
    'chicken wings': 'chicken',
    'chile': 'chili pepper',
    'chile flakes': 'chili pepper flakes',
    'chile pepper': 'chili pepper',
    'chile peppers': 'chili pepper',
    'chile powder': 'chili powder',
    'chilli': 'chili pepper',
    'chilli flakes': 'chili pepper flakes',
    'chilli powder': 'chili powder',
    'chipotle powder': 'chipotle chili powder',
    'chorizo sausage': 'chorizo',
    'ciabatta': 'bread',
    'ciabatta bread': 'bread',
    'cilantro sprigs': 'cilantro',
    'clear honey': 'honey',
    'cloves garlic': 'garlic',
    'coffee granules': 'coffee',
    "confectioners ' sugar": "confectioner 's sugar",
    'confectioners sugar': "confectioner 's sugar",
    'coriander': 'coriander seeds',
    'corn kernels': 'corn',
    'cornstarch': 'corn starch',
    'country bread': 'bread',
    'courgette': 'zucchini',
    'cracker crumbs': 'graham crackers',
    'cream tartar': 'cream of tartar',
    'creamy peanut butter': 'peanut butter',
    'cremini mushrooms': 'mushroom',
    'crimini mushrooms': 'mushroom',
    'crme frache': 'creme fraiche',
    'crunchy peanut butter': 'peanut butter',
    'crusty bread': 'bread',
    'crème fraîche': 'creme fraiche',
    'dark chocolate': 'chocolate',
    'dark chocolate chips': 'chocolate',
    'dark corn syrup': 'corn syrup',
    'dark molasses': 'molasses',
    'dark rum': 'rum',
    'dark sesame oil': 'sesame oil',
    'dark soy sauce': 'soy sauce',
    'demerara sugar': 'sugar',
    'diced green chiles': 'green chili pepper',
    'diced tomatoes': 'tomato',
    'dijon-style mustard': 'mustard',
    'dry mustard': 'mustard',
    'dry red wine': 'red wine',
    'dry sherry': 'sherry',
    'dry vermouth': 'vermouth',
    'dry white wine': 'white wine',
    'dry yeast': 'active dry yeast',
    'egg white': 'egg',
    'egg whites': 'egg',
    'egg yolk': 'egg',
    'egg yolks': 'egg',
    'english cucumber': 'cucumber',
    'english mustard powder': 'mustard',
    'espresso powder': 'espresso',
    'fat-free natural yoghurt': 'yogurt',
    'fennel bulb': 'fennel',
    'fennel bulbs': 'fennel',
    'fenugreek seeds': 'fenugreek',
    'feta': 'feta cheese',
    'firm tofu': 'tofu',
    'flaked almonds': 'almond',
    'flank steak': 'beef',
    'flatleaf parsley': 'flat-leaf parsley',
    'floury potatoes': 'potato',
    'free-range egg': 'egg',
    'free-range eggs': 'egg',
    'french baguette': 'baguette',
    'french bread': 'bread',
    'garlic clove': 'garlic',
    'gelatine': 'gelatin',
    'ginger root': 'ginger',
    'gold medal all purpose flour': 'all purpose flour',
    'golden raisins': 'raisin',
    'grain mustard': 'mustard',
    'grainy mustard': 'mustard',
    'greek yogurt': 'yogurt',
    'green bell peppers': 'green bell pepper',
    'green chile peppers': 'green chili pepper',
    'green chiles': 'green chili pepper',
    'green chilies': 'green chili pepper',
    'green chilli': 'green chili pepper',
    'green chillies': 'green chili pepper',
    'green onions': 'green onion',
    'gruyere cheese': 'gruyere',
    'gruyre': 'gruyere',
    'gruyre cheese': 'gruyere',
    'half-and-half cream': 'half-and-half',
    'harissa paste': 'harissa',
    'hass avocados': 'avocado',
    'head cabbage': 'cabbage',
    'head cauliflower': 'cauliflower',
    'heirloom tomatoes': 'tomato',
    'iceberg lettuce': 'lettuce',
    'instant espresso powder': 'espresso',
    'irish whiskey': 'whiskey',
    'italian parsley': 'flat-leaf parsley',
    'jalapeno': 'jalapeño',
    'jalapeno pepper': 'jalapeño',
    'jalapeno peppers': 'jalapeño',
    'jalapeo': 'jalapeño',
    'jalapeo pepper': 'jalapeño',
    'jalapeo peppers': 'jalapeño',
    'jalapeos': 'jalapeño',
    'juice lemon': 'lemon',
    'juice lemons': 'lemon',
    'juice lime': 'lime',
    'juice limes': 'lime',
    'juice orange': 'orange',
    'leaf parsley': 'flat-leaf parsley',
    'lemon grass': 'lemongrass',
    'lemon juice': 'lemon',
    'lemon peel': 'lemon zest',
    'lemon wedges': 'lemon',
    'light cream': 'cream',
    'light mayonnaise': 'mayonnaise',
    'light rum': 'rum',
    'lime juice': 'lime',
    'lime wedges': 'lime',
    'long-grain rice': 'rice',
    'long-grain white rice': 'rice',
    'low-fat buttermilk': 'buttermilk',
    'low-sodium chicken broth': 'chicken broth',
    'low-sodium soy sauce': 'soy sauce',
    'low-sodium vegetable broth': 'vegetable broth',
    'lump crabmeat': 'crabmeat',
    'mascarpone cheese': 'mascarpone',
    'mature cheddar': 'cheddar',
    'mayo': 'mayonnaise',
    'mild-flavored molasses': 'molasses',
    'mini chocolate chips': 'chocolate',
    'mini marshmallows': 'marshmallow',
    'miniature marshmallows': 'marshmallow',
    'mozzarella cheese': 'mozzarella',
    'muscovado sugar': 'sugar',
    'natural yogurt': 'yogurt',
    'old-fashioned oats': 'oat',
    'orange juice': 'orange',
    'orange juice concentrate': 'orange',
    'orange peel': 'orange',
    'package cream cheese': 'cream cheese',
    'panko breadcrumbs': 'bread crumbs',
    'parmesan': 'parmesan cheese',
    'parmigiano reggiano': 'parmesan cheese',
    'parmigiano-reggiano': 'parmesan cheese',
    'parmigiano-reggiano cheese': 'parmesan cheese',
    'pecan halves': 'pecan',
    'pecorino romano cheese': 'pecorino',
    'pepperjack cheese': 'pepper jack cheese',
    'pepperoni sausage': 'pepperoni',
    'pie shell': 'pie crust',
    'pineapple chunks': 'pineapple',
    'pineapple juice': 'pineapple',
    'pomegranate juice': 'pomegranate',
    'pork chops': 'pork',
    'pork loin': 'pork',
    'pork sausages': 'pork',
    'pork shoulder': 'pork',
    'pork tenderloin': 'pork',
    'pork tenderloins': 'pork',
    'porridge oats': 'oat',
    'red bell peppers': 'red bell pepper',
    'red chilies': 'red chili pepper',
    'red chilli': 'red chili pepper',
    'red chillies': 'red chili pepper',
    'red curry paste': 'curry paste',
    'red kidney beans': 'kidney beans',
    'red onions': 'red onion',
    'red pepper': 'red bell pepper',
    'red pepper flakes': 'chili pepper flakes',
    'red peppers': 'red bell pepper',
    'red potatoes': 'potato',
    'reduced-sodium soy sauce': 'soy sauce',
    'ricotta cheese': 'ricotta',
    'rocket': 'arugula',
    'roma tomatoes': 'tomato',
    'romano cheese': 'pecorino',
    'root ginger': 'ginger',
    'rosemary sprigs': 'rosemary',
    'runny honey': 'honey',
    'russet potato': 'potato',
    'russet potatoes': 'potato',
    'saffron threads': 'saffron',
    'salmon fillet': 'salmon',
    'salmon fillets': 'salmon',
    'sausage links': 'sausage',
    'scallion': 'green onion',
    'sea scallops': 'scallop',
    'semi-sweet chocolate chips': 'chocolate',
    'semisweet chocolate': 'chocolate',
    'semisweet chocolate chips': 'chocolate',
    'serrano chiles': 'serrano pepper',
    'sherry wine vinegar': 'sherry vinegar',
    'single cream': 'cream',
    'skinless chicken': 'chicken',
    'skirt steak': 'beef',
    'smith apple': 'granny smith apple',
    'smith apples': 'granny smith apple',
    'spring onions': 'green onion',
    'squeeze lemon juice': 'lemon',
    'sriracha': 'sriracha',
    'steak': 'beef',
    'stewed tomatoes': 'tomato',
    'streaky bacon': 'bacon',
    'sweet corn': 'corn',
    'sweet paprika': 'paprika',
    'sweet potatoes': 'sweet potato',
    'sweet vermouth': 'vermouth',
    'sweetcorn': 'corn',
    'tabasco sauce': 'tabasco',
    'thai red curry paste': 'curry paste',
    'thick-cut bacon': 'bacon',
    'thyme sprigs': 'thyme',
    'thyme thyme': 'thyme',
    'tilapia fillets': 'tilapia',
    'tin tomatoes': 'tomato',
    'tomato ketchup': 'ketchup',
    'tomatoes tomatoes': 'tomato',
    'tub mascarpone': 'mascarpone',
    'tuna steaks': 'tuna steaks',
    'vanilla bean': 'vanilla',
    'vanilla beans': 'vanilla',
    'vanilla pod': 'vanilla',
    'walnut halves': 'walnut',
    'well-shaken buttermilk': 'buttermilk',
    'white bread': 'bread',
    'white breadcrumbs': 'bread crumbs',
    'white mushrooms': 'mushroom',
    'white onion': 'onion',
    'white onions': 'onion',
    'white rum': 'rum',
    'white vinegar': 'vinegar',
    'whole almonds': 'almond',
    'whole cloves': 'clove',
    'whole tomatoes': 'tomato',
    'whole-grain mustard': 'mustard',
    'wholegrain mustard': 'mustard',
    'x tomatoes': 'tomato',
    'yeast': 'active dry yeast',
    'yellow mustard': 'mustard',
    'yellow onion': 'onion',
    'yellow onions': 'onion',
    'yellow pepper': 'yellow bell pepper',
    'yoghurt': 'yogurt',
    'zest lemon': 'lemon zest',
    'zest lemons': 'lemon zest',
    'zest orange': 'orange zest',
    'apple juice': 'apple',
    'apricot preserves': 'apricot',
    'baby arugula': 'arugula',
    'baby bok choy': 'bok choy',
    'baby carrots': 'carrot',
    'baby potatoes': 'potato',
    'baby spinach': 'spinach',
    'bacon bits': 'bacon',
    'beef brisket': 'beef',
    'beef chuck': 'beef',
    'beef mince': 'beef',
    'beef tenderloin': 'beef',
    'beet': 'beetroot',
    'black mustard seeds': 'mustard seeds',
    'butter lettuce': 'lettuce',
    'caramel sauce': 'caramel',
    'celery stalk': 'celery',
    'chili sauce': 'hot sauce',
    'chilies': 'chili pepper',
    'chocolate drops': 'chocolate',
    'coffee beans': 'coffee',
    'cranberry juice': 'cranberry',
    'cumin seeds': 'cumin',
    'curry paste': 'curry',
    'dijon mustard': 'mustard',
    'dill weed': 'dill',
    'english mustard': 'mustard',
    'grapefruit juice': 'grapefruit',
    'green pepper': 'green bell pepper',
    'lemon extract': 'lemon',
    'lemon zest': 'lemon zest',
    'lime zest': 'lime zest',
    'marshmallow creme': 'marshmallow',
    'medjool dates': 'date',
    'milk chocolate': 'chocolate',
    'milk chocolate chips': 'chocolate',
    'orange zest': 'orange zest',
    'pearl onions': 'onion',
    'pepper sauce': 'hot sauce',
    'pork sausage': 'pork',
    'sultana': 'raisin',
    'thai fish sauce': 'fish sauce',
    'tomato paste': 'tomato',
    'tomato puree': 'tomato',
    'vanilla ice cream': 'vanilla',
    'vanilla yogurt': 'vanilla',
    'vegetable broth': 'vegetable stock',
    'white balsamic vinegar': 'balsamic vinegar',
    'white chocolate chips': 'white chocolate',
    'almond extract': 'almond',
    'almond paste': 'almond',
    'asparagus spears': 'asparagus',
    'beef chuck': 'beef',
    'artichoke hearts': 'artichoke',
    'beef broth': 'beef stock',
    'celery stalk': 'celery',
    'chicken broth': 'chicken stock',
    'chilies': 'chili pepper',
    'chocolate chips': 'chocolate',
    'cocoa': 'cocoa powder',
    'coconut cream': 'coconut',
    'coconut extract': 'coconut',
    'coconut flakes': 'coconut',
    'coconut milk': 'coconut',
    'curry paste': 'curry',
    'curry powder': 'curry',
    'lemon zest': 'lemon zest',
    'mustard powder': 'mustard seeds',
    'onion powder': 'onion',
    'swiss chard': 'chard',
    'swiss cheese': 'cheese',
    'vegetable broth': 'vegetable stock'
}
categories = {
    'allspice': 'spice',
    'almond': 'nut',
    'almond milk': 'dairy',
    'american cheese': 'dairy',
    'anchovy': 'meat/fish',
    'andouille sausage': 'meat/fish',
    'angostura bitters': 'other',
    'anise': 'spice',
    'apple': 'produce',
    'apple cider': 'other',
    'apple cider vinegar': 'other',
    'applesauce': 'other',
    'apricot': 'produce',
    'apricot jam': 'other',
    'artichoke': 'produce',
    'arugula': 'produce',
    'asafetida': 'spice',
    'asparagus': 'produce',
    'avocado': 'produce',
    'bacon': 'meat/fish',
    'balsamic vinegar': 'other',
    'banana': 'produce',
    'barbecue sauce': 'other',
    'basil': 'herb',
    'basil pesto': 'other',
    'bay': 'herb',
    'bean sprouts': 'produce',
    'beef': 'meat/fish',
    'beef bouillon': 'other',
    'beef chuck': 'meat/fish',
    'beef stock': 'other',
    'beer': 'other',
    'beetroot': 'produce',
    'bell pepper': 'produce',
    'black beans': 'produce',
    'black olives': 'produce',
    'black-eyed peas': 'produce',
    'blackberry': 'produce',
    'blue cheese': 'dairy',
    'blueberry': 'produce',
    'bok choy': 'produce',
    'bourbon': 'other',
    'brandy': 'other',
    'breakfast sausage': 'meat/fish',
    'brie': 'dairy',
    'broad beans': 'produce',
    'broccoli': 'produce',
    'brussels sprouts': 'produce',
    'butter beans': 'produce',
    'buttermilk': 'dairy',
    'butternut squash': 'produce',
    'cabbage': 'produce',
    'cannellini beans': 'produce',
    'cantaloupe': 'produce',
    'caper': 'produce',
    'caramel': 'other',
    'caraway seeds': 'spice',
    'cardamom': 'spice',
    'carrot': 'produce',
    'cashew': 'nut',
    'cauliflower': 'produce',
    'cayenne pepper': 'spice',
    'celeriac': 'produce',
    'celery': 'produce',
    'celery seeds': 'spice',
    'champagne': 'other',
    'champagne vinegar': 'other',
    'chard': 'produce',
    'cheddar': 'dairy',
    'cheese': 'dairy',
    'cherry': 'produce',
    'cherry tomatoes': 'produce',
    'chervil': 'herb',
    'chestnut': 'produce',
    'chia seeds': 'nut',
    'chicken': 'meat/fish',
    'chicken broth': 'other',
    'chicken stock': 'other',
    'chickpea': 'produce',
    'chili pepper': 'produce',
    'chili pepper flakes': 'spice',
    'chili powder': 'spice',
    'chilies': 'produce',
    'chinese five-spice powder': 'spice',
    'chipotle chili powder': 'spice',
    'chipotle pepper': 'produce',
    'chive': 'herb',
    'chocolate': 'other',
    'chorizo': 'meat/fish',
    'cider vinegar': 'other',
    'cilantro': 'herb',
    'cinnamon': 'spice',
    'clam': 'meat/fish',
    'clove': 'spice',
    'cocoa powder': 'other',
    'coconut': 'produce',
    'coffee': 'other',
    'cognac': 'other',
    'cointreau': 'other',
    'condensed milk': 'dairy',
    'coriander seeds': 'spice',
    'corn': 'produce',
    'cotija cheese': 'dairy',
    'cottage cheese': 'dairy',
    'crabmeat': 'meat/fish',
    'cranberry': 'produce',
    'cream cheese': 'dairy',
    'cucumber': 'produce',
    'cumin': 'spice',
    'currant': 'produce',
    'curry': 'spice',
    'curry paste': 'spice',
    'date': 'produce',
    'dill': 'herb',
    'edamame': 'produce',
    'eggplant': 'produce',
    'espresso': 'other',
    'farro': 'nut',
    'fennel': 'produce',
    'fennel seeds': 'spice',
    'fenugreek': 'spice',
    'feta cheese': 'dairy',
    'fig': 'produce',
    'fish sauce': 'other',
    'fish stock': 'other',
    'flat-leaf parsley': 'herb',
    'fontina cheese': 'dairy',
    'garam masala': 'spice',
    'garbanzo beans': 'produce',
    'garlic': 'produce',
    'garlic powder': 'spice',
    'ghee': 'other',
    'gin': 'other',
    'ginger': 'produce',
    'ginger ale': 'other',
    'goat cheese': 'dairy',
    'gorgonzola cheese': 'dairy',
    'gouda cheese': 'dairy',
    'grand marnier': 'other',
    'granny smith apple': 'produce',
    'grape': 'produce',
    'grape tomatoes': 'produce',
    'grapefruit': 'produce',
    'green beans': 'produce',
    'green bell pepper': 'produce',
    'green cabbage': 'produce',
    'green cardamom': 'spice',
    'green chili pepper': 'produce',
    'green lentils': 'produce',
    'green olives': 'produce',
    'green onion': 'produce',
    'green peas': 'produce',
    'gruyere': 'dairy',
    'guacamole': 'other',
    'halloumi cheese': 'dairy',
    'ham': 'meat/fish',
    'harissa': 'spice',
    'hazelnut': 'produce',
    'hoisin sauce': 'other',
    'honey': 'other',
    'horseradish': 'produce',
    'italian sausage': 'meat/fish',
    'jack cheese': 'dairy',
    'jalapeño': 'produce',
    'jicama': 'produce',
    'juniper berries': 'spice',
    'kalamata olives': 'produce',
    'kale': 'produce',
    'kidney beans': 'produce',
    'lamb': 'meat/fish',
    'leek': 'produce',
    'lemon': 'produce',
    'lemon zest': 'produce',
    'lemongrass': 'herb',
    'lentil': 'produce',
    'lettuce': 'produce',
    'lime': 'produce',
    'macadamia nuts': 'nut',
    'mace': 'spice',
    'mandarin oranges': 'produce',
    'mango': 'produce',
    'maple syrup': 'other',
    'maraschino cherries': 'other',
    'marjoram': 'herb',
    'marsala wine': 'other',
    'marshmallow': 'other',
    'mascarpone': 'dairy',
    'mayonnaise': 'other',
    'mint': 'herb',
    'mirin': 'other',
    'mozzarella': 'dairy',
    'mushroom': 'produce',
    'mussel': 'meat/fish',
    'mustard': 'other',
    'mustard seeds': 'spice',
    'napa cabbage': 'produce',
    'nectarine': 'produce',
    'nutella': 'other',
    'nutmeg': 'spice',
    'okra': 'produce',
    'olive': 'produce',
    'onion': 'produce',
    'orange': 'produce',
    'orange bell pepper': 'produce',
    'orange liqueur': 'other',
    'orange marmalade': 'other',
    'orange zest': 'produce',
    'oregano': 'herb',
    'oyster': 'meat/fish',
    'oyster sauce': 'other',
    'pancetta': 'meat/fish',
    'paprika': 'spice',
    'parmesan cheese': 'dairy',
    'parsley': 'herb',
    'parsnip': 'produce',
    'pea': 'produce',
    'peach': 'produce',
    'peanut': 'nut',
    'peanut butter': 'other',
    'pear': 'produce',
    'pecan': 'nut',
    'pecorino': 'dairy',
    'pepitas': 'nut',
    'pepper jack cheese': 'dairy',
    'pepperoni': 'meat/fish',
    'pesto': 'other',
    'pine nuts': 'nut',
    'pineapple': 'produce',
    'pinto beans': 'produce',
    'pistachio': 'produce',
    'plum': 'produce',
    'plum tomatoes': 'produce',
    'poblano pepper': 'produce',
    'pomegranate': 'produce',
    'pomegranate seeds': 'produce',
    'poppy seeds': 'nut',
    'porcini mushrooms': 'produce',
    'pork': 'meat/fish',
    'port': 'other',
    'portobello mushrooms': 'produce',
    'potato': 'produce',
    'prawn': 'meat/fish',
    'prosciutto': 'meat/fish',
    'provolone cheese': 'dairy',
    'prune': 'produce',
    'pumpkin': 'produce',
    'pumpkin pie spice': 'spice',
    'pumpkin puree': 'other',
    'pumpkin seeds': 'nut',
    'queso fresco': 'dairy',
    'radicchio': 'produce',
    'radish': 'produce',
    'raisin': 'produce',
    'raspberry': 'produce',
    'red bell pepper': 'produce',
    'red cabbage': 'produce',
    'red chili pepper': 'produce',
    'red lentils': 'produce',
    'red onion': 'produce',
    'red wine': 'other',
    'red wine vinegar': 'other',
    'refried beans': 'produce',
    'rhubarb': 'produce',
    'rice wine vinegar': 'other',
    'ricotta': 'dairy',
    'romaine lettuce': 'produce',
    'rosemary': 'herb',
    'rum': 'other',
    'rye bread': 'other',
    'saffron': 'spice',
    'sage': 'herb',
    'sake': 'other',
    'salami': 'meat/fish',
    'salmon': 'meat/fish',
    'sauerkraut': 'other',
    'sausage': 'meat/fish',
    'savoy cabbage': 'produce',
    'scallop': 'meat/fish',
    'serrano pepper': 'produce',
    'sesame oil': 'other',
    'sesame seeds': 'nut',
    'shallot': 'produce',
    'sherry': 'other',
    'sherry vinegar': 'other',
    'shiitake mushrooms': 'produce',
    'shrimp': 'meat/fish',
    'smoked paprika': 'spice',
    'smoked salmon': 'meat/fish',
    'snow peas': 'produce',
    'soy milk': 'dairy',
    'soy sauce': 'other',
    'spinach': 'produce',
    'squash': 'produce',
    'sriracha': 'other',
    'star anise': 'spice',
    'strawberry': 'produce',
    'sugar snap peas': 'produce',
    'sumac': 'spice',
    'summer squash': 'produce',
    'sun-dried tomatoes': 'produce',
    'sunflower seeds': 'nut',
    'sweet potato': 'produce',
    'tabasco': 'other',
    'tahini': 'other',
    'tamari': 'other',
    'tamarind paste': 'other',
    'tarragon': 'herb',
    'tart cherries': 'produce',
    'tequila': 'other',
    'teriyaki sauce': 'other',
    'thyme': 'herb',
    'tilapia': 'meat/fish',
    'tofu': 'other',
    'tomatillo': 'produce',
    'tomato': 'produce',
    'tuna': 'meat/fish',
    'tuna steaks': 'meat/fish',
    'turkey': 'meat/fish',
    'turmeric': 'spice',
    'turnip': 'produce',
    'vanilla': 'spice',
    'veal': 'meat/fish',
    'vegetable broth': 'other',
    'vegetable stock': 'other',
    'vermouth': 'other',
    'vinegar': 'other',
    'vodka': 'other',
    'walnut': 'nut',
    'water chestnuts': 'produce',
    'watercress': 'produce',
    'watermelon': 'produce',
    'whiskey': 'other',
    'white beans': 'produce',
    'white chocolate': 'other',
    'white wine': 'other',
    'white wine vinegar': 'other',
    'worcestershire sauce': 'other',
    'yellow bell pepper': 'produce',
    'yellow squash': 'produce',
    'yogurt': 'dairy',
    'zucchini': 'produce',
    'lemon curd': 'other',
    'lime zest': 'produce'
}

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lmtzr = WordNetLemmatizer()

counter = count_ingredients(df['ingredients'].values, nsub=1)

def filter_ingredients(ingredients, firstRound=True, counter=counter):
    out = []
    for item in ingredients:
#         print(item, item in counter, counter[item] if item in counter else 0, item in ignore)
        if firstRound:
            condition = counter[item] > 10 and item not in ignore;
        else:
            condition = (counter[item] > 20 and
                         item not in ignore and
                         item in categories and
                         categories[item] != 'other')
        if item in counter and condition:
            lem = lmtzr.lemmatize(item)
            if lem not in ignore:
                if lem in mapping:
                    if mapping[lem] not in ignore:
                        out.append(mapping[lem])
                else:
                    out.append(lem)
#     print(ingredients, out)
    return out

newdf['curated_ingredients'] = newdf['ingredients'].map(filter_ingredients)
counter = count_ingredients(newdf['curated_ingredients'].values, nsub=1)
newdf['curated_ingredients'] = newdf['curated_ingredients'].map(lambda x: filter_ingredients(x, firstRound=False, counter=counter))
# Out:
# /Users/cooldjules/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/cooldjules/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Final list of ingredients

# %%
unique_ingredients = set([ing for inglist in newdf['curated_ingredients'].values for ing in inglist])
print(len(unique_ingredients))
for ing in sorted(unique_ingredients):
    print(ing)
# Out:
# 251
# allspice
# almond
# anchovy
# andouille sausage
# anise
# apple
# apricot
# artichoke
# arugula
# asafetida
# asparagus
# avocado
# bacon
# banana
# basil
# bay
# bean sprouts
# beef
# beetroot
# bell pepper
# black beans
# black olives
# black-eyed peas
# blackberry
# blue cheese
# blueberry
# bok choy
# brie
# broad beans
# broccoli
# brussels sprouts
# butter beans
# buttermilk
# butternut squash
# cabbage
# cannellini beans
# caper
# caraway seeds
# cardamom
# carrot
# cashew
# cauliflower
# cayenne pepper
# celeriac
# celery
# celery seeds
# chard
# cheddar
# cheese
# cherry
# cherry tomatoes
# chervil
# chestnut
# chicken
# chickpea
# chili pepper
# chili pepper flakes
# chili powder
# chinese five-spice powder
# chipotle chili powder
# chipotle pepper
# chive
# chorizo
# cilantro
# cinnamon
# clam
# clove
# coconut
# condensed milk
# coriander seeds
# corn
# cotija cheese
# cottage cheese
# crabmeat
# cranberry
# cream cheese
# cucumber
# cumin
# currant
# curry
# date
# ...

# %%
# from food2fork.ingredient_parser import parse as ingparse
# with open('food2fork/ingredient_parser/token_pos_tagged2.tsv', 'a') as outfile:
#     for ings in df.loc[0:1000, 'raw_ingredients']:
#         for ing in ings:
#             tokens = ingparse(ing)
#             for token, pos, cat in tokens:
#                 print(f'{token}\t{pos}\t{cat}', file=outfile)
#             print(file=outfile)

# %% [markdown]
# ### Most common food combinations

# %%
def most_common(values, nsub=2, nitems=50, distribution=None):
    pairs = count_ingredients(values, nsub=nsub)
    unique_ingredients = set([ing for inglist in values for ing in inglist])

    out = {}
    for ing in unique_ingredients:
        out[ing] = []
        count_dist = {}
        if distribution:
            for cat in distribution:
                count_dist[cat] = 0
        cnt = 0
        for (ing1, ing2), number in pairs.most_common():
            if number < 5:
                continue
            ing2add = None
            if ing1 == ing and ing2 != ing:
                ing2add = ing2
            elif ing2 == ing and ing1 != ing:
                ing2add = ing1
            if ing2add:
                cat = categories[ing2add]
                if (distribution is not None and
                        cat in distribution and
                        count_dist[cat] < distribution[cat]):
                    out[ing].append(ing2add)
                    count_dist[cat] += 1
                    cnt += 1
                elif distribution is None:
                    out[ing].append(ing2add)
                    cnt += 1
            if cnt == nitems:
                break

    return out

pairings = most_common(newdf['curated_ingredients'].values)

# %%
pairings['okra']
# Out:
# ['onion',
#  'garlic',
#  'tomato',
#  'celery',
#  'bay',
#  'thyme',
#  'cayenne pepper',
#  'green bell pepper',
#  'shrimp',
#  'andouille sausage',
#  'chicken',
#  'parsley',
#  'red bell pepper',
#  'green onion']

# %% [markdown]
# This data can then be copy-pasted into `data.js` for visualization.

# %%
pairings
# Out:
# {'allspice': ['onion',
#   'garlic',
#   'cinnamon',
#   'clove',
#   'thyme',
#   'cumin',
#   'tomato',
#   'cayenne pepper',
#   'ginger',
#   'bay',
#   'lime',
#   'green onion',
#   'lemon',
#   'coriander seeds',
#   'nutmeg',
#   'oregano',
#   'cilantro',
#   'beef',
#   'pork',
#   'chicken',
#   'carrot',
#   'orange',
#   'potato',
#   'paprika',
#   'parsley',
#   'jalapeño',
#   'chili powder',
#   'red onion',
#   'chili pepper flakes',
#   'celery',
#   'turmeric',
#   'raisin',
#   'apple',
#   'cheddar',
#   'bacon',
#   'lamb',
#   'sage',
#   'mint',
#   'yogurt',
#   'green bell pepper',
#   'flat-leaf parsley',
#   'juniper berries',
#   'coconut',
#   'mustard seeds',
#   'black beans',
#   'chili pepper',
#   'garlic powder',
#   'shallot',
#   'red bell pepper',
#   'rosemary'],
#  'almond': ['garlic',
#   'lemon',
#   'onion',
#   'coriander seeds',
#   'tomato',
#   'cumin',
#   'raisin',
#   'cinnamon',
#   'ginger',
#   'parmesan cheese',
# ...

# %% [markdown]
# ## Let's see if we can create a network of ingredients (using Graph theory and the networkx package)

# %%
import networkx as nx

# %%
# Insert processed data to mongodb
# client.food2forkDB.processed.insert_many(newdf.to_dict('records'))

# %%
newdf.columns
# Out:
# Index(['_id', 'cooktime', 'difficulty', 'f2f_url', 'image_url', 'media',
#        'nutrition', 'preptime', 'publisher', 'publisher_url', 'rating',
#        'raw_ingredients', 'recipe_id', 'reviews', 'social_rank', 'source_url',
#        'title', 'media_likes', 'media_tweets', 'media_plusses', 'media_pins',
#        'media_views', 'nmedia_likes', 'nmedia_tweets', 'nmedia_plusses',
#        'nmedia_pins', 'nmedia_views', 'media_rank', 'cooktime_mins',
#        'preptime_mins', 'totaltime_mins', 'ingredients', 'ingredients2',
#        'recipe_type', 'curated_ingredients'],
#       dtype='object')

# %%
dbprocessed = client.food2forkDB.processed
from numpy import log

def percent_ing(ingredient):
    '''Calculates the ratio between the total number of recipes containing an
    ingredient and the total number of recipes.
    '''
    if isinstance(ingredient, list):
        rci = dbprocessed.find({'curated_ingredients': {'$all': ingredient}}).count()
    else:
        rci = dbprocessed.find({'curated_ingredients': ingredient}).count()
    total_recipes = dbprocessed.find().count()
    return rci / total_recipes

def PMI(ing1, ing2):
    '''Calculates the Pointwise Mutual Information between 2 ingredients
    https://arxiv.org/pdf/1111.3919.pdf
    '''
    return log(percent_ing([ing1, ing2])/percent_ing(ing1)/percent_ing(ing2))

# %%
percent_ing(['avocado', 'cilantro', 'lime'])
# Out:
# 0.010018618671868073

# %%
PMI('avocado', 'onion')
# Out:
# -0.2651112783136569

# %%
len(unique_ingredients)
# Out:
# 251

# %%
pmis = {}

for ing1 in unique_ingredients:
    for ing2 in unique_ingredients:
        if ing1 != ing2:
            if ing1 not in pmis:
                pmis[ing1] = {}
            if ing2 not in pmis[ing1]:
                pmi12 = PMI(ing1, ing2)
                if pmi12 == -np.inf:
                    continue
                pmis[ing1][ing2] = pmi12
            if ing2 not in pmis:
                pmis[ing2] = {}
            if ing1 not in pmis[ing2]:
                pmis[ing2][ing1] = pmi12
# Out:
# /Users/cooldjules/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:19: RuntimeWarning: divide by zero encountered in log

# %%
sorted(pmis['butternut squash'].items(), key=lambda x: x[1])
# Out:
# [('bacon', -2.1178650597065576),
#  ('jalapeño', -1.810337486585099),
#  ('pork', -1.6476470452097058),
#  ('green bell pepper', -1.6056093320143128),
#  ('basil', -1.4392597207864102),
#  ('cucumber', -1.430062627305493),
#  ('garlic powder', -1.0785525133197396),
#  ('sesame seeds', -1.0192527710384478),
#  ('orange', -0.9562136611274954),
#  ('asparagus', -0.8246373033387762),
#  ('lettuce', -0.8207234040176397),
#  ('salmon', -0.8167941258777501),
#  ('beef', -0.8108711075746282),
#  ('black olives', -0.8049127979909976),
#  ('cream cheese', -0.6639549216483027),
#  ('cheddar', -0.6547382665433784),
#  ('mozzarella', -0.5541673597681165),
#  ('avocado', -0.5105684757138003),
#  ('fennel', -0.4779568901250393),
#  ('oregano', -0.46870613035288816),
#  ('plum tomatoes', -0.4612434091512987),
#  ('chicken', -0.42695433567266666),
#  ('green onion', -0.4243081314293933),
#  ('celery', -0.4202876443144774),
#  ('corn', -0.41721716039480816),
#  ('clove', -0.3974536712759688),
# ...

# %%
G = nx.Graph()

for ing in unique_ingredients:
    G.add_node(ing)

for ing1 in pmis:
    for ing2 in pmis[ing1]:
        if pmis[ing1][ing2] > 2 and not G.has_edge(ing1, ing2):
            G.add_edge(ing1, ing2, weight=pmis[ing1][ing2])

G.remove_nodes_from(nx.isolates(G))
deg = G.degree()
to_remove = [n for n in deg if deg[n] < 6]
G.remove_nodes_from(to_remove)

# %%
pos = nx.spring_layout(G)

# %%
from sklearn.cluster import KMeans
n_clusters = 4
model = KMeans(n_clusters=n_clusters)

posdf = pd.DataFrame(pos).transpose()

posdf['cluster'] = model.fit_predict(posdf)

# %%
clusters = [[node for node in G.nodes() if posdf.loc[node, 'cluster'] == cluster] for cluster in range(n_clusters)]

# %%
fig = plt.figure(figsize=(36, 20))
colors = ['red', 'steelblue', 'green', 'yellow', 'cyan']
for j, node_list in enumerate(clusters):
    nx.draw_networkx_nodes(G, pos, nodelist=node_list, node_size=100, node_color=colors[j])
nx.draw_networkx_edges(G, pos, width=0.5, alpha=0.4)
nx.draw_networkx_labels(G, pos, font_size=12)
G
